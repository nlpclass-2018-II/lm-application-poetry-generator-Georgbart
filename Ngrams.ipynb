# %%
import math
import nltk
import operator
from nltk import RegexpTokenizer

# %%
#First input & Tokenize
def startToken(input):
    tokenizer = RegexpTokenizer(r'(\w+)')
    file = open(input,'r')
    text = file.read()
    tokens = tokenizer.tokenize(text.lower())
    file.close()
    return tokens

#Further input & tokenizer
def getToken(tokens,input):
    tokenizer = RegexpTokenizer(r'(\w+)')
    file = open(input,'r')
    text = file.read()
    tokens += tokenizer.tokenize(text.lower())
    file.close()

# %%
tokens = startToken('Khairil Anwar.txt')
getToken(tokens,'Sapardi Darnomo.txt')
tokens
# Out:
# ['aku',
#  'kalau',
#  'sampai',
#  'waktuku',
#  'aku',
#  'mau',
#  'tak',
#  'seorang',
#  'kan',
#  'merayu',
#  'tidak',
#  'juga',
#  'kau',
#  'tak',
#  'perlu',
#  'sedan',
#  'itu',
#  'aku',
#  'ini',
#  'binatang',
#  'jalang',
#  'dari',
#  'kumpulannya',
#  'terbuang',
#  'biar',
#  'peluru',
#  'menembus',
#  'kulitku',
#  'aku',
#  'tetap',
#  'meradang',
#  'menerjang',
#  'luka',
#  'dan',
#  'bisa',
#  'kubawa',
#  'berlari',
#  'berlari',
#  'hingga',
#  'hilang',
#  'pedih',
#  'peri',
#  'dan',
#  'aku',
#  'akan',
#  'lebih',
#  'tidak',
#  'peduli',
#  'aku',
#  'mau',
#  'hidup',
#  'seribu',
#  'tahun',
#  'lagi',
#  'aku',
#  'berkaca',
#  'ini',
#  'muka',
#  'penuh',
#  'luka',
#  'siapa',
#  'punya',
#  'ku',
#  'dengar',
#  'seru',
#  'menderu',
#  'dalam',
#  'hatiku',
#  'apa',
#  'hanya',
#  'angin',
#  'lalu',
#  'lagi',
#  'lain',
#  'pula',
#  'menggelepar',
#  'tengah',
#  'malam',
#  'buta',
#  'ah',
#  'segala',
#  'menebal',
#  'segala',
#  'mengental',
#  'segala',
#  'tak',
#  'ku',
#  'kenal',
#  'selamat',
#  'tinggal',
#  'diponegoro',
#  'di',
#  'masa',
#  'pembangunan',
#  'ini',
#  'tuan',
#  'hidup',
#  'kembali',
#  'dan',
#  'bara',
#  'kagum',
#  'menjadi',
#  'api',
#  'di',
#  'depan',
#  'sekali',
#  'tuan',
#  'menanti',
#  'tak',
#  'gentar',
#  'lawan',
#  'banyaknya',
#  'seratus',
#  'kali',
#  'pedang',
#  'di',
#  'kanan',
#  'keris',
#  'di',
#  'kiri',
#  'berselempang',
#  'semangat',
#  'yang',
#  'tak',
#  'bisa',
#  'mati',
#  'doa',
#  'kepada',
#  'pemeluk',
#  'teguh',
#  'tuhanku',
#  'dalam',
#  'termangu',
#  'aku',
#  'masih',
#  'menyebut',
#  'namamu',
#  'biar',
#  'susah',
#  'sungguh',
#  'mengingat',
#  'kau',
#  'penuh',
#  'seluruh',
#  'cahaya',
#  'mu',
#  'panas',
#  'suci',
#  'tinggal',
#  'kerdip',
#  'lilin',
#  'di',
#  'kelam',
#  'sunyi',
#  'tuhanku',
#  'aku',
#  'hilang',
#  'bentuk',
#  'remuk',
#  'tuhanku',
#  'aku',
#  'mengembara',
#  'di',
#  'negeri',
#  'asing',
#  'tuhanku',
#  'di',
#  'pintu',
#  'mu',
#  'aku',
#  'bisa',
#  'mengetuk',
#  'aku',
#  'tidak',
#  'bisa',
#  'berpaling',
#  'krawang',
#  'bekasi',
#  'kami',
#  'yang',
#  'kini',
#  'terbaring',
#  'antara',
#  'krawang',
#  'bekasi',
#  'tidak',
#  'bisa',
#  'teriak',
#  'merdeka',
#  'dan',
#  'angkat',
#  'senjata',
#  'lagi',
#  'tapi',
#  'siapakah',
#  'yang',
#  'tidak',
#  'lagi',
#  'mendengar',
#  'deru',
#  'kami',
#  'terbayang',
#  'kami',
#  'maju',
#  'dan',
#  'mendegap',
#  'hati',
#  'kami',
#  'bicara',
#  'padamu',
#  'dalam',
#  'hening',
#  'di',
#  'malam',
#  'sepi',
#  'jika',
#  'dada',
#  'rasa',
#  'hampa',
#  'dan',
#  'jam',
#  'dinding',
#  'yang',
#  'berdetak',
#  'kami',
#  'mati',
#  'muda',
#  'yang',
#  'tinggal',
#  'tulang',
#  'diliputi',
#  'debu',
#  'kenang',
#  'kenanglah',
#  'kami',
#  'kami',
#  'sudah',
#  'coba',
#  'apa',
#  'yang',
#  'kami',
#  'bisa',
#  'tapi',
#  'kerja',
#  'belum',
#  'selesai',
#  'belum',
#  'bisa',
#  'memperhitungkan',
#  'ati',
#  '4',
#  '5',
#  'ribu',
#  'nyawa',
#  'kami',
#  'cuma',
#  'tulang',
#  'tulang',
#  'berserakan',
#  'tapi',
#  'adalah',
#  'kepunyaanmu',
#  'kaulah',
#  'lagi',
#  'yang',
#  'tentukan',
#  'nilai',
#  'tulang',
#  'tulang',
#  'berserakan',
#  'atau',
#  'jiwa',
#  'kami',
#  'melayang',
#  'untuk',
#  'kemerdekaan',
#  'kemenangan',
#  'dan',
#  'harapan',
#  'atau',
#  'tidak',
#  'untuk',
#  'apa',
#  'apa',
#  'kami',
#  'tidak',
#  'tahu',
#  'kami',
#  'tidak',
#  'lagi',
#  'bisa',
#  'berkata',
#  'kaulah',
#  'sekarang',
#  'yang',
#  'berkata',
#  'kami',
#  'bicara',
#  'padamu',
#  'dalam',
#  'hening',
#  'di',
#  'malam',
#  'sepi',
#  'jika',
#  'ada',
#  'rasa',
#  'hampa',
#  'dan',
#  'jam',
#  'dinding',
#  'yang',
#  'berdetak',
#  'kenang',
#  'kenang',
#  'lah',
#  'kami',
#  'teruskan',
#  'teruskan',
#  'jiwa',
#  'kami',
#  'menjaga',
#  'bung',
#  'karno',
#  'menjaga',
#  'bung',
#  'hatta',
#  'menjaga',
#  'bung',
#  'sjahrir',
#  'kami',
#  'sekarang',
#  'mayat',
#  'berikan',
#  'kami',
#  'arti',
#  'berjagalah',
#  'terus',
#  'di',
#  'garis',
#  'batas',
#  'pernyataan',
#  'dan',
#  'impian',
#  'kenang',
#  'kenang',
#  'lah',
#  'kami',
#  'yang',
#  'tinggal',
#  'tulang',
#  'tulang',
#  'diliputi',
#  'debu',
#  'beribu',
#  'kami',
#  'terbaring',
#  'antara',
#  'krawang',
#  'bekasi',
#  'maju',
#  'bagimu',
#  'negeri',
#  'menyediakan',
#  'api',
#  'punah',
#  'di',
#  'atas',
#  'menghamba',
#  'binasa',
#  'di',
#  'atas',
#  'ditindas',
#  'sesungguhnya',
#  'jalan',
#  'ajal',
#  'baru',
#  'tercapai',
#  'jika',
#  'hidup',
#  'harus',
#  'merasai',
#  'maju',
#  'serbu',
#  'serang',
#  'terjang',
#  'yang',
#  'terampas',
#  'dan',
#  'yang',
#  'putus',
#  'kelam',
#  'dan',
#  'angin',
#  'lalu',
#  'mempesiang',
#  'diriku',
#  'menggigir',
#  'juga',
#  'ruang',
#  'di',
#  'mana',
#  'dia',
#  'yang',
#  'ku',
#  'ingin',
#  'malam',
#  'tambah',
#  'merasuk',
#  'rimba',
#  'jadi',
#  'semati',
#  'tugu',
#  'di',
#  'karet',
#  'di',
#  'karet',
#  'daerahku',
#  'y',
#  'a',
#  'd',
#  'sampai',
#  'juga',
#  'deru',
#  'dingin',
#  'aku',
#  'berbenah',
#  'dalam',
#  'kamar',
#  'dalam',
#  'diriku',
#  'jika',
#  'kau',
#  'datang',
#  'dan',
#  'aku',
#  'bis',
#  'lagi',
#  'lepaskan',
#  'kisah',
#  'baru',
#  'padamu',
#  'tapi',
#  'kini',
#  'hanya',
#  'tangan',
#  'yang',
#  'bergerak',
#  'lantang',
#  'tubuhku',
#  'diam',
#  'dan',
#  'sendiri',
#  'cerita',
#  'dan',
#  'peristiwa',
#  'berlaku',
#  'beku',
#  'hampa',
#  'sepi',
#  'di',
#  'luar',
#  'sepi',
#  'menekan',
#  'mendesak',
#  'lurus',
#  'kaku',
#  'pohonan',
#  'tak',
#  'bergerak',
#  'sampai',
#  'ke',
#  'puncak',
#  'sepi',
#  'memagut',
#  'tak',
#  'satu',
#  'kuasa',
#  'melepas',
#  'renggut',
#  'segala',
#  'menanti',
#  'menanti',
#  'menanti',
#  'sepi',
#  'tambah',
#  'ini',
#  'menanti',
#  'jadi',
#  'mencekik',
#  'memberat',
#  'mencekung',
#  'punda',
#  'sampai',
#  'binasa',
#  'segala',
#  'belum',
#  'apa',
#  'apa',
#  'udara',
#  'bertuba',
#  'setan',
#  'bertampik',
#  'ini',
#  'sepi',
#  'terus',
#  'ada',
#  'dan',
#  'menanti',
#  'senja',
#  'di',
#  'pelabuhan',
#  'kecil',
#  'ini',
#  'kali',
#  'tidak',
#  'ada',
#  'yang',
#  'mencari',
#  'cinta',
#  'di',
#  'antara',
#  'gudang',
#  'rumah',
#  'tua',
#  'pada',
#  'cerita',
#  'tiang',
#  'serta',
#  'temali',
#  'kapal',
#  'perahu',
#  'tiada',
#  'berlaut',
#  'menghembus',
#  'diri',
#  'dalam',
#  'mempercaya',
#  'mau',
#  'berpaut',
#  'gerimis',
#  'mempercepat',
#  'kelam',
#  'ada',
#  'juga',
#  'kelepak',
#  'elang',
#  'menyinggung',
#  'muram',
#  'desir',
#  'hari',
#  'lari',
#  'berenang',
#  'menemu',
#  'bujuk',
#  'pangkal',
#  'akanan',
#  'tidak',
#  'bergerak',
#  'dan',
#  'kini',
#  'tanah',
#  'air',
#  'tidur',
#  'hilang',
#  'ombak',
#  'tiada',
#  'lagi',
#  'aku',
#  'sendirian',
#  'berjalan',
#  'menyisir',
#  'semenanjung',
#  'masih',
#  'pengap',
#  'harap',
#  'sekali',
#  'tiba',
#  'di',
#  'ujung',
#  'dan',
#  'sekalian',
#  'selamat',
#  'jalan',
#  'dari',
#  'pantai',
#  'keempat',
#  'sedu',
#  'penghabisan',
#  'bisa',
#  'terdekap',
#  'kepada',
#  'kawan',
#  'sebelum',
#  'ajal',
#  'mendekat',
#  'dan',
#  'menghianat',
#  'mencengkam',
#  'dari',
#  'belakang',
#  'ketika',
#  'kita',
#  'tidak',
#  'melihat',
#  'selama',
#  'masih',
#  'menggelombang',
#  'dalam',
#  'dada',
#  'darah',
#  'serta',
#  'rasa',
#  'belum',
#  'bertugas',
#  'kecewa',
#  'dan',
#  'gentar',
#  'belum',
#  'ada',
#  'tidak',
#  'lupa',
#  'tiba',
#  'tiba',
#  'bisa',
#  'malam',
#  'membenam',
#  'layar',
#  'merah',
#  'berkibar',
#  'hilang',
#  'dalam',
#  'kelam',
#  'kawan',
#  'mari',
#  'kita',
#  'putuskan',
#  'kini',
#  'di',
#  'sini',
#  'ajal',
#  'yang',
#  'menarik',
#  'kita',
#  'juga',
#  'mencekik',
#  'diri',
#  'sendiri',
#  'jadi',
#  'isi',
#  'gelas',
#  'sepenuhnya',
#  'lantas',
#  'kosongkan',
#  'tembus',
#  'jelajah',
#  'dunia',
#  'ini',
#  'dan',
#  'balikkan',
#  'peluk',
#  'kucup',
#  'perempuan',
#  'tinggalkan',
#  'kalau',
#  'merayu',
#  'pilih',
#  'kuda',
#  'yang',
#  'paling',
#  'liar',
#  'pacu',
#  'laju',
#  'jangan',
#  'tembatkan',
#  'pada',
#  'siang',
#  'dan',
#  'malam',
#  'dan',
#  'hancurkan',
#  'lagi',
#  'apa',
#  'yang',
#  'kau',
#  'perbuat',
#  'hilang',
#  'sonder',
#  'pusaka',
#  'sonder',
#  'kerabat',
#  'tidak',
#  'minta',
#  'ampun',
#  'atas',
#  'segala',
#  'dosa',
#  'tidak',
#  'memberi',
#  'pamit',
#  'siapa',
#  'saja',
#  'jadi',
#  'mari',
#  'kita',
#  'putuskan',
#  'sekali',
#  'lagi',
#  'ajal',
#  'yang',
#  'menarik',
#  'kita',
#  'kan',
#  'merasa',
#  'angkasa',
#  'sepi',
#  'sekali',
#  'lagi',
#  'kawan',
#  'sebaris',
#  'lagi',
#  'tikamkan',
#  'pedangmu',
#  'hingga',
#  'ke',
#  'hulu',
#  'pada',
#  'siapa',
#  'yang',
#  'mengairi',
#  'kemurnian',
#  'madu',
#  'cerita',
#  'buat',
#  'dien',
#  'tamaela',
#  'beta',
#  'pattirajawane',
#  'yang',
#  'dijaga',
#  'datu',
#  'datu',
#  'cuma',
#  'satu',
#  'beta',
#  'pattirajawane',
#  'kikisan',
#  'laut',
#  'berdarah',
#  'laut',
#  'beta',
#  'pattirajawane',
#  'ketika',
#  'lahir',
#  'dibawakan',
#  'datu',
#  'dayung',
#  'sampan',
#  'beta',
#  'pattirajawane',
#  'menjaga',
#  'hutan',
#  'pala',
#  'beta',
#  'api',
#  'di',
#  'pantai',
#  'siapa',
#  'mendekat',
#  'tiga',
#  'kali',
#  'menyebut',
#  'beta',
#  'punya',
#  'nama',
#  'dalam',
#  'sunyi',
#  'malam',
#  'ganggang',
#  'menari',
#  'menurut',
#  'beta',
#  'punya',
#  'tifa',
#  'pohon',
#  'pala',
#  'badan',
#  'perawan',
#  'jadi',
#  'hidup',
#  'sampai',
#  'pagi',
#  'tiba',
#  'mari',
#  'menari',
#  'mari',
#  'beria',
#  'mari',
#  'berlupa',
#  'awas',
#  'jangan',
#  'bikin',
#  'beta',
#  'marah',
#  'beta',
#  'bikin',
#  'pala',
#  'mati',
#  'gadis',
#  'kaku',
#  'beta',
#  'kirim',
#  'datu',
#  'datu',
#  'beta',
#  'ada',
#  'di',
#  'malam',
#  'ada',
#  'di',
#  'siang',
#  'irama',
#  'ganggang',
#  'dan',
#  'api',
#  'membakar',
#  'pulau',
#  'beta',
#  'pattirajawane',
#  'yang',
#  'dijaga',
#  'datu',
#  'datu',
#  'cuma',
#  'satu',
#  'persetujuan',
#  'dengan',
#  'bung',
#  'karno',
#  'ayo',
#  'bung',
#  'karno',
#  'kasih',
#  'tangan',
#  'mari',
#  'kita',
#  'bikin',
#  'janji',
#  'aku',
#  'sudah',
#  'cukup',
#  'lama',
#  'dengan',
#  'bicara',
#  'mu',
#  'dipanggang',
#  'di',
#  'atas',
#  'api',
#  'mu',
#  'digarami',
#  'lautmu',
#  'dari',
#  'mulai',
#  'tanggal',
#  '17',
#  'agusutus',
#  '1945',
#  'aku',
#  'melangkah',
#  'ke',
#  'depan',
#  'berada',
#  'rapat',
#  'di',
#  'sisimu',
#  'aku',
#  'sekarang',
#  'api',
#  'aku',
#  'sekarang',
#  'laut',
#  'bung',
#  'karno',
#  'kau',
#  'dan',
#  'aku',
#  'satu',
#  'zat',
#  'satu',
#  'urat',
#  'di',
#  'zat',
#  'mu',
#  'di',
#  'zat',
#  'ku',
#  'kapal',
#  'kapakl',
#  'kita',
#  'berlayar',
#  'di',
#  'urat',
#  'mu',
#  'di',
#  'urat',
#  'ku',
#  'kapal',
#  'kapal',
#  'kita',
#  'bertolak',
#  'dan',
#  'berlabuh',
#  'sebuah',
#  'kamar',
#  'sebuah',
#  'jendela',
#  'menyerahkan',
#  'kamar',
#  'ini',
#  'pada',
#  'dunia',
#  'bulan',
#  'yang',
#  'menyinar',
#  'ke',
#  'dalam',
#  'mau',
#  'lebih',
#  'banyak',
#  'tahu',
#  'sudah',
#  'lima',
#  'anak',
#  'bernyawa',
#  'di',
#  'sini',
#  'aku',
#  'salah',
#  'satu',
#  'ibuku',
#  'tertidur',
#  'dalam',
#  'tersedu',
#  'keramaian',
#  'penjara',
#  'sepi',
#  'selalu',
#  'bapak',
#  'ku',
#  'sendiri',
#  'terbaring',
#  'jemu',
#  'matanya',
#  'menatap',
#  'orang',
#  'tersalib',
#  'di',
#  'batu',
#  'sekeliling',
#  'dunia',
#  'bunuh',
#  'diri',
#  'aku',
#  'minta',
#  'adik',
#  'lagi',
#  'pada',
#  'ibu',
#  'dan',
#  'bapak',
#  'ku',
#  'karena',
#  'mereka',
#  'berada',
#  'di',
#  'luar',
#  'hitungan',
#  'kamar',
#  'begini',
#  '3',
#  'x',
#  '4',
#  'terlalu',
#  'sempit',
#  'buat',
#  'meniup',
#  'nyawa',
#  'rumahku',
#  'rumah',
#  'ku',
#  'dari',
#  'unggun',
#  'timbun',
#  'sajak',
#  'kaca',
#  'jernih',
#  'dari',
#  'luar',
#  'segala',
#  ...]

# %%
len(tokens)
# Out:
# 1515

# %%
#Build Unigram table/model
def getUnigram(tokens):
    unigram = {}
    unigram_count = 0
    for token in tokens:
        if token in unigram:
            unigram[token] += 1
        else:
            unigram[token] = 1
            unigram_count += 1
    return unigram, unigram_count

# %%
unigram, ucount = getUnigram(tokens)
unigram
# Out:
# {'17': 1,
#  '1945': 1,
#  '3': 1,
#  '4': 2,
#  '5': 1,
#  'a': 1,
#  'abadi': 3,
#  'abu': 2,
#  'ada': 13,
#  'adalah': 5,
#  'adik': 1,
#  'agar': 1,
#  'agusutus': 1,
#  'ah': 1,
#  'air': 3,
#  'ajal': 4,
#  'akan': 6,
#  'akanan': 1,
#  'akar': 1,
#  'aku': 36,
#  'ampun': 1,
#  'anak': 1,
#  'angin': 5,
#  'angkasa': 1,
#  'angkat': 1,
#  'antara': 5,
#  'apa': 9,
#  'api': 9,
#  'arif': 1,
#  'arti': 1,
#  'asing': 1,
#  'atas': 4,
#  'atau': 2,
#  'ati': 1,
#  'awan': 1,
#  'awas': 1,
#  'ayo': 1,
#  'badan': 1,
#  'bagiku': 2,
#  'bagimu': 1,
#  'bahagia': 1,
#  'bahasa': 1,
#  'bait': 2,
#  'balikkan': 1,
#  'banyak': 1,
#  'banyaknya': 1,
#  'bapak': 2,
#  'bara': 1,
#  'baru': 2,
#  'basah': 1,
#  'batas': 1,
#  'batu': 2,
#  'begini': 1,
#  'bekasi': 3,
#  'beku': 1,
#  'belakang': 1,
#  'belum': 5,
#  'bentuk': 1,
#  'berada': 2,
#  'beranak': 1,
#  'berbaring': 1,
#  'berbenah': 1,
#  'berbini': 1,
#  'berbunga': 1,
#  'berdarah': 1,
#  'berdenyut': 1,
#  'berdetak': 2,
#  'berenang': 1,
#  'bergelut': 1,
#  'bergerak': 3,
#  'beria': 1,
#  'beribu': 1,
#  'berikan': 1,
#  'berjagalah': 1,
#  'berjalan': 1,
#  'berkaca': 1,
#  'berkata': 2,
#  'berkhianat': 1,
#  'berkibar': 1,
#  'berlabuh': 1,
#  'berlaku': 1,
#  'berlari': 2,
#  'berlaut': 1,
#  'berlayar': 1,
#  'berleleran': 1,
#  'berlupa': 1,
#  'bernyawa': 1,
#  'berpaling': 1,
#  'berpaut': 1,
#  'bersamamu': 1,
#  'bersandar': 1,
#  'berselempang': 1,
#  'berserakan': 2,
#  'bertahan': 1,
#  'bertampik': 1,
#  'bertolak': 1,
#  'bertuba': 1,
#  'bertudung': 1,
#  'bertugas': 1,
#  'beta': 12,
#  'biar': 3,
#  'biarkan': 1,
#  'bicara': 3,
#  'bijak': 1,
#  'bikin': 3,
#  'bilang': 1,
#  'binasa': 2,
#  'binatang': 1,
#  'bis': 1,
#  'bisa': 12,
#  'buat': 2,
#  'bujuk': 1,
#  'bukan': 1,
#  'bulan': 5,
#  'bung': 6,
#  'bunga': 4,
#  'bunuh': 1,
#  'burung': 1,
#  'buta': 1,
#  'cahaya': 2,
#  'cakrawala': 1,
#  'cerita': 3,
#  'cinta': 2,
#  'ciptakan': 1,
#  'coba': 1,
#  'cukup': 1,
#  'cuma': 3,
#  'd': 1,
#  'dada': 2,
#  'dadaku': 2,
#  'daerahku': 1,
#  'dalam': 18,
#  'dan': 32,
#  'dapat': 1,
#  'darah': 2,
#  'dari': 13,
#  'datang': 3,
#  'datangnya': 1,
#  'datu': 7,
#  'daun': 5,
#  'dayung': 1,
#  'debu': 2,
#  'demi': 1,
#  'dendam': 1,
#  'dengan': 7,
#  'dengar': 1,
#  'depan': 2,
#  'depanku': 1,
#  'deru': 2,
#  'desir': 1,
#  'detik': 2,
#  'di': 42,
#  'dia': 1,
#  'diam': 1,
#  'dibawakan': 1,
#  'dibiarkannya': 1,
#  'dien': 1,
#  'digarami': 1,
#  'dihamilkan': 1,
#  'dihapuskannya': 1,
#  'dijaga': 2,
#  'dikenal': 1,
#  'diliputi': 2,
#  'dinding': 2,
#  'dingin': 1,
#  'dipanggang': 1,
#  'diponegoro': 1,
#  'dirahasiakannya': 1,
#  'diri': 3,
#  'dirikan': 1,
#  'diriku': 4,
#  'disampaikan': 1,
#  'diserap': 1,
#  'ditindas': 1,
#  'diucapkan': 1,
#  'doa': 1,
#  'dosa': 1,
#  'dulu': 1,
#  'dunia': 3,
#  'elang': 1,
#  'entah': 1,
#  'fana': 3,
#  'gadis': 1,
#  'ganggang': 2,
#  'garis': 1,
#  'gedong': 1,
#  'gelas': 1,
#  'gentar': 2,
#  'gerimis': 1,
#  'gudang': 1,
#  'gunung': 1,
#  'halaman': 1,
#  'hampa': 3,
#  'hancurkan': 1,
#  'hanya': 2,
#  'harap': 1,
#  'harapan': 1,
#  'hari': 6,
#  'harum': 1,
#  'harus': 7,
#  'hasrat': 1,
#  'hati': 1,
#  'hatiku': 3,
#  'hatta': 1,
#  'hening': 2,
#  'hidup': 5,
#  'hidupku': 1,
#  'hilang': 5,
#  'hingga': 2,
#  'hitam': 1,
#  'hitungan': 1,
#  'hujan': 8,
#  'hulu': 1,
#  'huruf': 1,
#  'hutan': 1,
#  'ibu': 1,
#  'ibuku': 1,
#  'impian': 1,
#  'impianku': 1,
#  'ingin': 6,
#  'ini': 12,
#  'irama': 1,
#  'isi': 1,
#  'isyarat': 1,
#  'itu': 5,
#  'jadi': 5,
#  'jalan': 4,
#  'jalang': 1,
#  'jam': 2,
#  'jangan': 3,
#  'janji': 2,
#  'jarak': 1,
#  'jasadku': 1,
#  'jatuh': 1,
#  'jejak': 2,
#  'jelajah': 1,
#  'jemu': 1,
#  'jendela': 1,
#  'jernih': 1,
#  'jika': 5,
#  'jilat': 1,
#  'jiwa': 4,
#  'juga': 5,
#  'juni': 4,
#  'kabut': 1,
#  'kaca': 1,
#  'kagum': 1,
#  'kakinya': 1,
#  'kaku': 2,
#  'kala': 1,
#  'kalau': 2,
#  'kali': 4,
#  'kamar': 4,
#  'kami': 19,
#  'kan': 2,
#  'kanan': 1,
#  'kapakl': 1,
#  'kapal': 4,
#  'karena': 1,
#  'karet': 2,
#  'karno': 4,
#  'kasih': 1,
#  'kata': 2,
#  'kau': 12,
#  'kaulah': 2,
#  'kawan': 3,
#  'kayu': 1,
#  'ke': 6,
#  'kecewa': 1,
#  'kecil': 2,
#  'keempat': 1,
#  'keindahan': 1,
#  'kelam': 4,
#  'kelebat': 1,
#  'kelepak': 1,
#  'kemah': 1,
#  'kembali': 1,
#  'kembang': 1,
#  'kemenangan': 1,
#  'kemerdekaan': 1,
#  'kemurnian': 1,
#  'kenal': 1,
#  'kenang': 5,
#  'kenanglah': 1,
#  'kepada': 6,
#  'kepunyaanmu': 1,
#  'kerabat': 1,
#  'keramaian': 1,
#  'kerdip': 1,
#  'keris': 1,
#  'kerja': 1,
#  'ketika': 4,
#  'kikisan': 1,
#  'kini': 5,
#  'kiri': 1,
#  'kirim': 1,
#  'kisah': 1,
#  'kita': 12,
#  'kolam': 1,
#  'kosongkan': 1,
#  'krawang': 3,
#  'ku': 12,
#  'kuasa': 1,
#  'kubawa': 1,
#  'kucari': 1,
#  'kucup': 1,
#  'kuda': 1,
#  'kuhentikan': 2,
#  'kulitku': 1,
#  'kumpulannya': 1,
#  'kurelakan': 1,
#  'kusiasati': 1,
#  'kutolak': 1,
#  'ladang': 1,
#  'lagi': 18,
#  'lagu': 1,
#  'lah': 2,
#  'lahir': 1,
#  'lain': 1,
#  'laju': 1,
#  'lalu': 2,
#  'lama': 3,
#  'lantang': 1,
#  'lantas': 1,
#  'lari': 2,
#  'larik': 2,
#  'laut': 3,
#  'lautmu': 1,
#  'lawan': 1,
#  'layar': 1,
#  'lebar': 1,
#  'lebih': 6,
#  'lepaskan': 1,
#  'letih': 1,
#  'letihnya': 1,
#  'liar': 1,
#  'lilin': 1,
#  'lima': 1,
#  'luar': 3,
#  'luka': 3,
#  'lupa': 2,
#  'luput': 1,
#  'lurus': 1,
#  'madu': 2,
#  'maju': 3,
#  'makna': 1,
#  'malam': 9,
#  'mana': 2,
#  'manis': 1,
#  'marah': 1,
#  'mari': 6,
#  'masa': 1,
#  'masih': 4,
#  'matahari': 3,
#  'matamu': 2,
#  'matanya': 1,
#  'mati': 4,
#  'mau': 4,
#  'mawar': 1,
#  'mayat': 1,
#  'melangkah': 1,
#  'melati': 1,
#  'melayang': 2,
#  'melepas': 1,
#  'melihat': 1,
#  'memagut': 1,
#  'memaksaku': 1,
#  'membakar': 1,
#  'membayangkan': 1,
#  'membelah': 1,
#  'membenam': 1,
#  'membenci': 1,
#  'memberat': 1,
#  'memberi': 1,
#  'memerdu': 2,
#  'memimpikan': 1,
#  'mempercaya': 1,
#  'mempercayai': 1,
#  'mempercepat': 1,
#  'memperhitungkan': 1,
#  'mempesiang': 1,
#  'memungut': 1,
#  'menagih': 1,
#  'menanti': 6,
#  'menari': 3,
#  'menarik': 3,
#  'menatap': 1,
#  'mencari': 1,
#  'mencekik': 2,
#  'mencekung': 1,
#  'mencengkam': 1,
#  'mencintai': 6,
#  'mencintaimu': 2,
#  'mencintamu': 1,
#  'menciptakan': 1,
#  'mencoba': 1,
#  'mendegap': 1,
#  'mendekat': 2,
#  'mendengar': 1,
#  'menderu': 1,
#  'mendesak': 1,
#  'mendoa': 1,
#  'menebal': 1,
#  'menebas': 1,
#  'menekan': 1,
#  'menembus': 2,
#  'menemu': 1,
#  'menengadah': 1,
#  'menerjang': 1,
#  'menerjemahkanku': 1,
#  'mengairi': 1,
#  'mengalir': 1,
#  'mengalun': 1,
#  'mengangkat': 1,
#  'mengembara': 1,
#  'mengental': 1,
#  'mengetuk': 1,
#  'menggelepar': 1,
#  'menggelombang': 1,
#  'menggigir': 1,
#  'menghamba': 1,
#  'menghembus': 1,
#  'menghianat': 1,
#  'mengingat': 1,
#  'meninabobokan': 1,
#  'meniup': 1,
#  'menjadi': 6,
#  'menjadikannya': 2,
#  'menjaga': 4,
#  'menurut': 1,
#  'menyaksikanmu': 1,
#  'menyanyi': 1,
#  'menyebut': 2,
#  'menyediakan': 1,
#  'menyerahkan': 1,
#  'menyinar': 1,
#  'menyinggung': 1,
#  'menyisir': 1,
#  'meradang': 1,
#  'merah': 1,
#  'meraih': 1,
#  'merangkainya': 1,
#  'merasa': 1,
#  'merasai': 1,
#  'merasuk': 1,
#  'merayu': 2,
#  'merdeka': 1,
#  'mereka': 1,
#  'meriak': 1,
#  'merindukanku': 1,
#  'minta': 2,
#  'mu': 7,
#  'muda': 1,
#  'muka': 2,
#  'mulai': 1,
#  'muram': 1,
#  'nama': 1,
#  'namamu': 1,
#  'nampak': 1,
#  'namun': 1,
#  'nanti': 5,
#  'negeri': 2,
#  'nilai': 1,
#  'nyawa': 2,
#  'ombak': 1,
#  'orang': 1,
#  'pacu': 1,
#  'pada': 11,
#  'padam': 1,
#  'padamu': 3,
#  'pagi': 4,
#  'pala': 3,
#  'paling': 1,
#  'pamit': 1,
#  'panas': 1,
#  'pandang': 1,
#  'pangkal': 1,
#  'pantai': 2,
#  'pattirajawane': 5,
#  'pedang': 1,
#  'pedangmu': 1,
#  'pedih': 1,
#  'peduli': 1,
#  'pelabuhan': 1,
#  'pelangi': 1,
#  'peluk': 1,
#  'peluru': 1,
#  'pembangunan': 1,
#  'pemeluk': 1,
#  'pengap': 1,
#  'penghabisan': 1,
#  'penjara': 1,
#  'penuh': 2,
#  'perahu': 1,
#  'perawan': 1,
#  'perbuat': 1,
#  'perempuan': 1,
#  'peri': 1,
#  'peristiwa': 1,
#  'perlahan': 1,
#  'perlu': 1,
#  'pernyataan': 1,
#  'persetujuan': 1,
#  'petang': 1,
#  'pilih': 1,
#  'pintu': 2,
#  'pohon': 3,
#  'pohonan': 1,
#  'pula': 1,
#  'pulau': 1,
#  'pun': 1,
#  'punah': 1,
#  'puncak': 1,
#  'punda': 1,
#  'punya': 3,
#  'pusaka': 1,
#  'putih': 1,
#  'putus': 1,
#  'putuskan': 2,
#  'ragu': 2,
#  'rambutmu': 1,
#  'ranting': 2,
#  'rapat': 1,
#  'rasa': 3,
#  'rasanya': 1,
#  'remuk': 1,
#  'renggut': 1,
#  'ribu': 1,
#  'ricik': 1,
#  'rimba': 1,
#  'rindunya': 1,
#  'rintik': 1,
#  'ruang': 1,
#  'rumah': 3,
#  'rumahku': 1,
#  'rumput': 1,
#  'saja': 2,
#  'sajak': 8,
#  'salah': 1,
#  'sampai': 6,
#  'sampan': 1,
#  'sapu': 1,
#  'satu': 7,
#  'sebagai': 2,
#  'sebaris': 1,
#  'sebelum': 2,
#  'sebuah': 2,
#  'sedan': 1,
#  'sederhana': 3,
#  'sedu': 1,
#  'segala': 7,
#  'sejenak': 1,
#  'sekali': 5,
#  'sekalian': 1,
#  'sekarang': 4,
#  'sekeliling': 1,
#  'sela': 2,
#  'selalu': 1,
#  'selama': 4,
#  'selamat': 2,
#  'selembar': 4,
#  'selesai': 1,
#  'seluruh': 2,
#  'semangat': 1,
#  'semati': 1,
#  'semenanjung': 1,
#  'sempat': 2,
#  'sempit': 1,
#  'senantiasa': 1,
#  'senda': 1,
#  'sendiri': 4,
#  'sendirian': 1,
#  'senja': 3,
#  'senjata': 1,
#  'seorang': 1,
#  'sepenuhnya': 1,
#  'seperti': 1,
#  'sepi': 10,
#  'serang': 1,
#  'seratus': 1,
#  'serbu': 1,
#  'seribu': 1,
#  'serta': 2,
#  'seru': 1,
#  'sesaat': 1,
#  'sesungguhnya': 1,
#  'setan': 1,
#  'setiap': 1,
#  'siang': 2,
#  'siapa': 4,
#  'siapakah': 1,
#  'sini': 4,
#  'sisimu': 1,
#  'siut': 1,
#  'sjahrir': 1,
#  'sonder': 2,
#  'sore': 1,
#  'suara': 1,
#  'suaraku': 1,
#  'suatu': 5,
#  'suci': 1,
#  'sudah': 3,
#  'suka': 1,
#  'sungai': 1,
#  'sungguh': 1,
#  'sunyi': 2,
#  'susah': 1,
#  'sutra': 1,
#  'tabah': 1,
#  'tafsir': 1,
#  'tafsirkan': 1,
#  'tafsirkanaku': 1,
#  'tahu': 2,
#  'tahun': 1,
#  'tak': 20,
#  'tamaela': 1,
#  'taman': 1,
#  'tambah': 2,
#  'tanah': 3,
#  'tangan': 2,
#  'tanggal': 1,
#  'tanyamu': 1,
#  'tapi': 8,
#  'tari': 1,
#  'teguh': 1,
#  'temali': 1,
#  'tembatkan': 1,
#  'tembus': 1,
#  'tengah': 1,
#  'tentang': 1,
#  'tentukan': 1,
#  'terakhir': 3,
#  'terampas': 1,
#  'terbang': 1,
#  'terbaring': 3,
#  'terbayang': 1,
#  'terbuang': 1,
#  'terbuka': 1,
#  'tercapai': 1,
#  'terdekap': 1,
#  'terdengar': 1,
#  'teriak': 1,
#  'terjal': 1,
#  'terjang': 1,
#  'terlalu': 1,
#  'termangu': 1,
#  'tersalib': 1,
#  'tersedu': 1,
#  'tersesat': 1,
#  'tertidur': 1,
#  'terucapkan': 1,
#  'terus': 2,
#  'teruskan': 2,
#  'tetap': 2,
#  'tiada': 3,
#  'tiang': 1,
#  'tiba': 6,
#  'tidak': 18,
#  'tidur': 1,
#  'tifa': 1,
#  'tiga': 1,
#  'tikamkan': 1,
#  'timbun': 2,
#  'tinggal': 4,
#  'tinggalkan': 1,
#  'tolong': 3,
#  'tua': 1,
#  'tuan': 2,
#  'tubuhku': 1,
#  'tugu': 1,
#  'tuhanku': 4,
#  'tulang': 7,
#  'udara': 1,
#  'ujung': 1,
#  'unggun': 2,
#  'untuk': 4,
#  'urat': 3,
#  'waktu': 3,
#  'waktuku': 1,
#  'warna': 1,
#  'x': 1,
#  'y': 1,
#  'yang': 46,
#  'zat': 3}

# %%
ucount
# Out:
# 684

# %%
#Build Bigram table/model
def getBigram(tokens):
    length = len(tokens)
    bigram = {}
    bigram_count = 0
    for x in range(0, length - 1):
        if tokens[x] in bigram:
            if tokens[x + 1] in bigram[tokens[x]]:
                bigram[tokens[x]][tokens[x + 1]] += 1
            else:
                bigram[tokens[x]][tokens[x + 1]] = 1
                bigram_count += 1
        else:
            bigram[tokens[x]] = {}
            bigram[tokens[x]][tokens[x + 1]] = 1
            bigram_count += 1
    return bigram, bigram_count

# %%
bigram, bcount = getBigram(tokens)
print(bcount)
bigram
# Out:
# 1341
# {'17': {'agusutus': 1},
#  '1945': {'aku': 1},
#  '3': {'x': 1},
#  '4': {'5': 1, 'terlalu': 1},
#  '5': {'ribu': 1},
#  'a': {'d': 1},
#  'abadi': {'memungut': 1, 'sajak': 1, 'sebelum': 1},
#  'abu': {'aku': 1, 'tolong': 1},
#  'ada': {'dan': 1,
#   'di': 2,
#   'juga': 1,
#   'lagi': 1,
#   'rasa': 1,
#   'tidak': 1,
#   'yang': 6},
#  'adalah': {'abadi': 1, 'kepunyaanmu': 1, 'waktu': 3},
#  'adik': {'lagi': 1},
#  'agar': {'suara': 1},
#  'agusutus': {'1945': 1},
#  'ah': {'segala': 1},
#  'air': {'harus': 1, 'kolam': 1, 'tidur': 1},
#  'ajal': {'baru': 1, 'mendekat': 1, 'yang': 2},
#  'akan': {'ada': 1,
#   'kurelakan': 1,
#   'lebih': 1,
#   'letih': 1,
#   'menerjemahkanku': 1,
#   'tetap': 1},
#  'akanan': {'tidak': 1},
#  'akar': {'pohon': 1},
#  'aku': {'akan': 1,
#   'berbenah': 1,
#   'berbini': 1,
#   'berkaca': 1,
#   'bis': 1,
#   'bisa': 1,
#   'burung': 1,
#   'hidup': 1,
#   'hilang': 1,
#   'ingin': 3,
#   'ini': 1,
#   'kalau': 1,
#   'masih': 1,
#   'mau': 2,
#   'melangkah': 1,
#   'mengembara': 1,
#   'minta': 1,
#   'pada': 1,
#   'salah': 1,
#   'satu': 1,
#   'sebagai': 1,
#   'sejenak': 1,
#   'sekarang': 2,
#   'selembar': 2,
#   'sendirian': 1,
#   'sudah': 1,
#   'tersesat': 1,
#   'tetap': 1,
#   'tidak': 3},
#  'ampun': {'atas': 1},
#  'anak': {'bernyawa': 1},
#  'angin': {'aku': 1, 'harus': 1, 'lalu': 2, 'yang': 1},
#  'angkasa': {'sepi': 1},
#  'angkat': {'senjata': 1},
#  'antara': {'gudang': 1, 'kita': 1, 'krawang': 2, 'larik': 1},
#  'apa': {'apa': 2,
#   'hanya': 1,
#   'kami': 1,
#   'saja': 1,
#   'tapi': 1,
#   'udara': 1,
#   'yang': 2},
#  'api': {'aku': 1,
#   'di': 2,
#   'harus': 1,
#   'membakar': 1,
#   'mu': 1,
#   'punah': 1,
#   'yang': 2},
#  'arif': {'dari': 1},
#  'arti': {'berjagalah': 1},
#  'asing': {'tuhanku': 1},
#  'atas': {'api': 1, 'ditindas': 1, 'menghamba': 1, 'segala': 1},
#  'atau': {'jiwa': 1, 'tidak': 1},
#  'ati': {'4': 1},
#  'awan': {'kepada': 1},
#  'awas': {'jangan': 1},
#  'ayo': {'bung': 1},
#  'badan': {'perawan': 1},
#  'bagiku': {'apa': 1, 'menengadah': 1},
#  'bagimu': {'negeri': 1},
#  'bahagia': {'ketika': 1},
#  'bahasa': {'abu': 1},
#  'bait': {'bait': 1, 'sajak': 1},
#  'balikkan': {'peluk': 1},
#  'banyak': {'tahu': 1},
#  'banyaknya': {'seratus': 1},
#  'bapak': {'ku': 2},
#  'bara': {'kagum': 1},
#  'baru': {'padamu': 1, 'tercapai': 1},
#  'basah': {'dendam': 1},
#  'batas': {'pernyataan': 1},
#  'batu': {'aku': 1, 'sekeliling': 1},
#  'begini': {'3': 1},
#  'bekasi': {'kami': 1, 'maju': 1, 'tidak': 1},
#  'beku': {'hampa': 1},
#  'belakang': {'ketika': 1},
#  'belum': {'ada': 1, 'apa': 1, 'bertugas': 1, 'bisa': 1, 'selesai': 1},
#  'bentuk': {'remuk': 1},
#  'berada': {'di': 1, 'rapat': 1},
#  'beranak': {'rasanya': 1},
#  'berbaring': {'di': 1},
#  'berbenah': {'dalam': 1},
#  'berbini': {'dan': 1},
#  'berbunga': {'itu': 1},
#  'berdarah': {'laut': 1},
#  'berdenyut': {'dalam': 1},
#  'berdetak': {'kami': 1, 'kenang': 1},
#  'berenang': {'menemu': 1},
#  'bergelut': {'senda': 1},
#  'bergerak': {'dan': 1, 'lantang': 1, 'sampai': 1},
#  'beria': {'mari': 1},
#  'beribu': {'kami': 1},
#  'berikan': {'kami': 1},
#  'berjagalah': {'terus': 1},
#  'berjalan': {'menyisir': 1},
#  'berkaca': {'ini': 1},
#  'berkata': {'kami': 1, 'kaulah': 1},
#  'berkhianat': {'kepada': 1},
#  'berkibar': {'hilang': 1},
#  'berlabuh': {'sebuah': 1},
#  'berlaku': {'beku': 1},
#  'berlari': {'berlari': 1, 'hingga': 1},
#  'berlaut': {'menghembus': 1},
#  'berlayar': {'di': 1},
#  'berleleran': {'kata': 1},
#  'berlupa': {'awas': 1},
#  'bernyawa': {'di': 1},
#  'berpaling': {'krawang': 1},
#  'berpaut': {'gerimis': 1},
#  'bersamamu': {'tolong': 1},
#  'bersandar': {'pada': 1},
#  'berselempang': {'semangat': 1},
#  'berserakan': {'atau': 1, 'tapi': 1},
#  'bertahan': {'di': 1},
#  'bertampik': {'ini': 1},
#  'bertolak': {'dan': 1},
#  'bertuba': {'setan': 1},
#  'bertudung': {'sutra': 1},
#  'bertugas': {'kecewa': 1},
#  'beta': {'ada': 1,
#   'api': 1,
#   'bikin': 1,
#   'kirim': 1,
#   'marah': 1,
#   'pattirajawane': 5,
#   'punya': 2},
#  'biar': {'berleleran': 1, 'peluru': 1, 'susah': 1},
#  'biarkan': {'aku': 1},
#  'bicara': {'mu': 1, 'padamu': 2},
#  'bijak': {'dari': 1},
#  'bikin': {'beta': 1, 'janji': 1, 'pala': 1},
#  'bilang': {'aku': 1},
#  'binasa': {'di': 1, 'segala': 1},
#  'binatang': {'jalang': 1},
#  'bis': {'lagi': 1},
#  'bisa': {'berkata': 1,
#   'berpaling': 1,
#   'kubawa': 1,
#   'kutolak': 1,
#   'lebih': 1,
#   'malam': 1,
#   'mati': 1,
#   'memperhitungkan': 1,
#   'mengetuk': 1,
#   'tapi': 1,
#   'terdekap': 1,
#   'teriak': 1},
#  'buat': {'dien': 1, 'meniup': 1},
#  'bujuk': {'pangkal': 1},
#  'bukan': {'tanyamu': 1},
#  'bulan': {'juni': 4, 'yang': 1},
#  'bung': {'hatta': 1, 'karno': 4, 'sjahrir': 1},
#  'bunga': {'bunga': 1, 'hujan': 1, 'itu': 1, 'sampai': 1},
#  'bunuh': {'diri': 1},
#  'burung': {'jangan': 1},
#  'buta': {'ah': 1},
#  'cahaya': {'matahari': 1, 'mu': 1},
#  'cakrawala': {'harus': 1},
#  'cerita': {'buat': 1, 'dan': 1, 'tiang': 1},
#  'cinta': {'di': 1, 'mencintai': 1},
#  'ciptakan': {'makna': 1},
#  'coba': {'apa': 1},
#  'cukup': {'lama': 1},
#  'cuma': {'satu': 2, 'tulang': 1},
#  'd': {'sampai': 1},
#  'dada': {'darah': 1, 'rasa': 1},
#  'dadaku': {'memerdu': 2},
#  'daerahku': {'y': 1},
#  'dalam': {'bahasa': 1,
#   'bait': 1,
#   'dada': 1,
#   'dadaku': 2,
#   'diriku': 2,
#   'hatiku': 1,
#   'hening': 2,
#   'kamar': 1,
#   'kelam': 1,
#   'mau': 1,
#   'mempercaya': 1,
#   'mendoa': 1,
#   'sunyi': 1,
#   'termangu': 1,
#   'tersedu': 1},
#  'dan': {'aku': 3,
#   'angin': 1,
#   'angkat': 1,
#   'api': 1,
#   'balikkan': 1,
#   'bapak': 1,
#   'bara': 1,
#   'batu': 1,
#   'beranak': 1,
#   'berlabuh': 1,
#   'bisa': 1,
#   'cahaya': 1,
#   'dalam': 2,
#   'gentar': 1,
#   'hancurkan': 1,
#   'harapan': 1,
#   'impian': 1,
#   'jam': 2,
#   'kini': 1,
#   'malam': 1,
#   'melati': 1,
#   'menanti': 1,
#   'mendegap': 1,
#   'menghianat': 1,
#   'peristiwa': 1,
#   'sekalian': 1,
#   'sendiri': 1,
#   'yang': 1},
#  'dapat': {'jalan': 1},
#  'darah': {'mengalir': 1, 'serta': 1},
#  'dari': {'belakang': 1,
#   'gedong': 1,
#   'hidupku': 1,
#   'hujan': 3,
#   'kumpulannya': 1,
#   'luar': 1,
#   'luka': 1,
#   'mulai': 1,
#   'pantai': 1,
#   'unggun': 2},
#  'datang': {'aku': 1, 'dan': 1, 'tidak': 1},
#  'datangnya': {'datang': 1},
#  'datu': {'beta': 1, 'cuma': 2, 'datu': 3, 'dayung': 1},
#  'daun': {'hatiku': 1, 'melayang': 1, 'terakhir': 3},
#  'dayung': {'sampan': 1},
#  'debu': {'beribu': 1, 'kenang': 1},
#  'demi': {'detik': 1},
#  'dendam': {'yang': 1},
#  'dengan': {'bicara': 1, 'bung': 1, 'isyarat': 1, 'kata': 1, 'sederhana': 3},
#  'dengar': {'seru': 1},
#  'depan': {'berada': 1, 'sekali': 1},
#  'depanku': {'bertudung': 1},
#  'deru': {'dingin': 1, 'kami': 1},
#  'desir': {'hari': 1},
#  'detik': {'demi': 1, 'merangkainya': 1},
#  'di': {'antara': 2,
#   'atas': 3,
#   'batu': 1,
#   'bulan': 1,
#   'depan': 1,
#   'garis': 1,
#   'hitam': 1,
#   'jalan': 1,
#   'kanan': 1,
#   'karet': 2,
#   'kelam': 1,
#   'kiri': 1,
#   'luar': 2,
#   'malam': 3,
#   'mana': 1,
#   'masa': 1,
#   'negeri': 1,
#   'pagi': 1,
#   'pantai': 1,
#   'pelabuhan': 1,
#   'pintu': 1,
#   'ranting': 1,
#   'rumput': 1,
#   'sela': 1,
#   'siang': 1,
#   'sini': 4,
#   'sisimu': 1,
#   'ujung': 1,
#   'urat': 2,
#   'zat': 2},
#  'dia': {'yang': 1},
#  'diam': {'dan': 1},
#  'dibawakan': {'datu': 1},
#  'dibiarkannya': {'yang': 1},
#  'dien': {'tamaela': 1},
#  'digarami': {'lautmu': 1},
#  'dihamilkan': {'hujan': 1},
#  'dihapuskannya': {'jejak': 1},
#  'dijaga': {'datu': 2},
#  'dikenal': {'lagi': 1},
#  'diliputi': {'debu': 2},
#  'dinding': {'yang': 2},
#  'dingin': {'aku': 1},
#  'dipanggang': {'di': 1},
#  'diponegoro': {'di': 1},
#  'dirahasiakannya': {'rintik': 1},
#  'diri': {'aku': 1, 'dalam': 1, 'sendiri': 1},
#  'dirikan': {'ketika': 1},
#  'diriku': {'jika': 1, 'menembus': 1, 'menggigir': 1, 'yang': 1},
#  'disampaikan': {'awan': 1},
#  'diserap': {'akar': 1},
#  'ditindas': {'sesungguhnya': 1},
#  'diucapkan': {'kayu': 1},
#  'doa': {'kepada': 1},
#  'dosa': {'tidak': 1},
#  'dulu': {'biarkan': 1},
#  'dunia': {'bulan': 1, 'bunuh': 1, 'ini': 1},
#  'elang': {'menyinggung': 1},
#  'entah': {'ke': 1},
#  'fana': {'adalah': 3},
#  'gadis': {'kaku': 1},
#  'ganggang': {'dan': 1, 'menari': 1},
#  'garis': {'batas': 1},
#  'gedong': {'lebar': 1},
#  'gelas': {'sepenuhnya': 1},
#  'gentar': {'belum': 1, 'lawan': 1},
#  'gerimis': {'mempercepat': 1},
#  'gudang': {'rumah': 1},
#  'gunung': {'harus': 1},
#  'halaman': {'aku': 1},
#  'hampa': {'dan': 2, 'sepi': 1},
#  'hancurkan': {'lagi': 1},
#  'hanya': {'angin': 1, 'tangan': 1},
#  'harap': {'sekali': 1},
#  'harapan': {'atau': 1},
#  'hari': {'kita': 1, 'lari': 1, 'nanti': 4},
#  'harum': {'rambutmu': 1},
#  'harus': {'menebas': 1, 'menjadi': 5, 'merasai': 1},
#  'hasrat': {'untuk': 1},
#  'hati': {'kami': 1},
#  'hatiku': {'apa': 1, 'selembar': 2},
#  'hatta': {'menjaga': 1},
#  'hening': {'di': 2},
#  'hidup': {'dari': 1, 'harus': 1, 'kembali': 1, 'sampai': 1, 'seribu': 1},
#  'hidupku': {'pintu': 1},
#  'hilang': {'bentuk': 1, 'dalam': 1, 'ombak': 1, 'pedih': 1, 'sonder': 1},
#  'hingga': {'hilang': 1, 'ke': 1},
#  'hitam': {'matamu': 1},
#  'hitungan': {'kamar': 1},
#  'hujan': {'bulan': 3,
#   'dan': 1,
#   'di': 1,
#   'kini': 1,
#   'kuhentikan': 1,
#   'yang': 1},
#  'hulu': {'pada': 1},
#  'huruf': {'sajak': 1},
#  'hutan': {'pala': 1},
#  'ibu': {'dan': 1},
#  'ibuku': {'tertidur': 1},
#  'impian': {'kenang': 1},
#  'impianku': {'pun': 1},
#  'ingin': {'ku': 1,
#   'malam': 1,
#   'mencintaimu': 2,
#   'mencintamu': 1,
#   'menyaksikanmu': 1},
#  'ini': {'binatang': 1,
#   'dan': 1,
#   'kali': 1,
#   'kau': 3,
#   'menanti': 1,
#   'muka': 1,
#   'pada': 1,
#   'senantiasa': 1,
#   'sepi': 1,
#   'tuan': 1},
#  'irama': {'ganggang': 1},
#  'isi': {'gelas': 1},
#  'isyarat': {'yang': 1},
#  'itu': {'aku': 1, 'padam': 1, 'tak': 2, 'yang': 1},
#  'jadi': {'hidup': 1, 'isi': 1, 'mari': 1, 'mencekik': 1, 'semati': 1},
#  'jalan': {'ajal': 1, 'dari': 1, 'itu': 1, 'kemah': 1},
#  'jalang': {'dari': 1},
#  'jam': {'dinding': 2},
#  'jangan': {'bikin': 1, 'sekali': 1, 'tembatkan': 1},
#  'janji': {'aku': 1, 'api': 1},
#  'jarak': {'mencintai': 1},
#  'jasadku': {'tak': 1},
#  'jatuh': {'di': 1},
#  'jejak': {'jejak': 1, 'kakinya': 1},
#  'jelajah': {'dunia': 1},
#  'jemu': {'matanya': 1},
#  'jendela': {'menyerahkan': 1},
#  'jernih': {'dari': 1},
#  'jika': {'ada': 1, 'dada': 1, 'hidup': 1, 'kau': 1, 'menagih': 1},
#  'jilat': {'mencintai': 1},
#  'jiwa': {'dan': 2, 'kami': 2},
#  'juga': {'deru': 1, 'kau': 1, 'kelepak': 1, 'mencekik': 1, 'ruang': 1},
#  'juni': {'dibiarkannya': 1,
#   'dihapuskannya': 1,
#   'dirahasiakannya': 1,
#   'tak': 1},
#  'kabut': {'pagi': 1},
#  'kaca': {'jernih': 1},
#  'kagum': {'menjadi': 1},
#  'kakinya': {'yang': 1},
#  'kaku': {'beta': 1, 'pohonan': 1},
#  'kala': {'di': 1},
#  'kalau': {'merayu': 1, 'sampai': 1},
#  'kali': {'berkhianat': 1, 'menyebut': 1, 'pedang': 1, 'tidak': 1},
#  'kamar': {'begini': 1, 'dalam': 1, 'ini': 1, 'sebuah': 1},
#  'kami': {'arti': 1,
#   'bicara': 2,
#   'bisa': 1,
#   'cuma': 1,
#   'kami': 1,
#   'maju': 1,
#   'mati': 1,
#   'melayang': 1,
#   'menjaga': 1,
#   'sekarang': 1,
#   'sudah': 1,
#   'terbaring': 1,
#   'terbayang': 1,
#   'teruskan': 1,
#   'tidak': 2,
#   'yang': 2},
#  'kan': {'merasa': 1, 'merayu': 1},
#  'kanan': {'keris': 1},
#  'kapakl': {'kita': 1},
#  'kapal': {'kapakl': 1, 'kapal': 1, 'kita': 1, 'perahu': 1},
#  'karena': {'mereka': 1},
#  'karet': {'daerahku': 1, 'di': 1},
#  'karno': {'ayo': 1, 'kasih': 1, 'kau': 1, 'menjaga': 1},
#  'kasih': {'tangan': 1},
#  'kata': {'manis': 1, 'yang': 1},
#  'kau': {'akan': 1,
#   'bilang': 1,
#   'dan': 1,
#   'darah': 1,
#   'datang': 1,
#   'depanku': 1,
#   'penuh': 1,
#   'perbuat': 1,
#   'sapu': 1,
#   'tak': 3},
#  'kaulah': {'lagi': 1, 'sekarang': 1},
#  'kawan': {'mari': 1, 'sebaris': 1, 'sebelum': 1},
#  'kayu': {'kepada': 1},
#  'ke': {'dalam': 2, 'depan': 1, 'hulu': 1, 'mana': 1, 'puncak': 1},
#  'kecewa': {'dan': 1},
#  'kecil': {'ini': 1, 'tentang': 1},
#  'keempat': {'sedu': 1},
#  'keindahan': {'kelebat': 1},
#  'kelam': {'ada': 1, 'dan': 1, 'kawan': 1, 'sunyi': 1},
#  'kelebat': {'diriku': 1},
#  'kelepak': {'elang': 1},
#  'kemah': {'ku': 1},
#  'kembali': {'dan': 1},
#  'kembang': {'mawar': 1},
#  'kemenangan': {'dan': 1},
#  'kemerdekaan': {'kemenangan': 1},
#  'kemurnian': {'madu': 1},
#  'kenal': {'selamat': 1},
#  'kenang': {'kenang': 2, 'kenanglah': 1, 'lah': 2},
#  'kenanglah': {'kami': 1},
#  'kepada': {'api': 1,
#   'hujan': 1,
#   'kawan': 1,
#   'pemeluk': 1,
#   'pohon': 1,
#   'sungai': 1},
#  'kepunyaanmu': {'kaulah': 1},
#  'kerabat': {'tidak': 1},
#  'keramaian': {'penjara': 1},
#  'kerdip': {'lilin': 1},
#  'keris': {'di': 1},
#  'kerja': {'belum': 1},
#  'ketika': {'kita': 1, 'lahir': 1, 'senja': 1, 'sore': 1},
#  'kikisan': {'laut': 1},
#  'kini': {'di': 1, 'hanya': 1, 'matahari': 1, 'tanah': 1, 'terbaring': 1},
#  'kiri': {'berselempang': 1},
#  'kirim': {'datu': 1},
#  'kisah': {'baru': 1},
#  'kita': {'abadi': 2,
#   'berlayar': 1,
#   'bertolak': 1,
#   'bikin': 1,
#   'juga': 1,
#   'kan': 1,
#   'lupa': 1,
#   'mati': 1,
#   'putuskan': 2,
#   'tidak': 1},
#  'kolam': {'jiwa': 1},
#  'kosongkan': {'tembus': 1},
#  'krawang': {'bekasi': 3},
#  'ku': {'dari': 2,
#   'dengar': 1,
#   'dirikan': 1,
#   'ingin': 1,
#   'kapal': 2,
#   'karena': 1,
#   'kenal': 1,
#   'lari': 1,
#   'pandang': 1,
#   'sendiri': 1},
#  'kuasa': {'melepas': 1},
#  'kubawa': {'berlari': 1},
#  'kucup': {'perempuan': 1},
#  'kuda': {'yang': 1},
#  'kuhentikan': {'hujan': 2},
#  'kulitku': {'aku': 1},
#  'kumpulannya': {'terbuang': 1},
#  'kurelakan': {'sendiri': 1},
#  'kusiasati': {'pada': 1},
#  'kutolak': {'matahari': 1},
#  'ladang': {'dan': 1},
#  'lagi': {'ajal': 1,
#   'aku': 2,
#   'apa': 1,
#   'bisa': 1,
#   'kawan': 1,
#   'lain': 1,
#   'lepaskan': 1,
#   'mendengar': 1,
#   'meraih': 1,
#   'namun': 1,
#   'pada': 1,
#   'tapi': 4,
#   'tikamkan': 1,
#   'yang': 1},
#  'lagu': {'menarik': 1},
#  'lah': {'kami': 2},
#  'lahir': {'dibawakan': 1},
#  'lain': {'pula': 1},
#  'laju': {'jangan': 1},
#  'lalu': {'lagi': 1, 'mempesiang': 1},
#  'lama': {'bersamamu': 1, 'dengan': 1, 'lagi': 1},
#  'lantang': {'tubuhku': 1},
#  'lantas': {'kosongkan': 1},
#  'lari': {'berenang': 1, 'dari': 1},
#  'larik': {'larik': 1, 'sajak': 1},
#  'laut': {'berdarah': 1, 'beta': 1, 'bung': 1},
#  'lautmu': {'dari': 1},
#  'lawan': {'banyaknya': 1},
#  'layar': {'merah': 1},
#  'lebar': {'halaman': 1},
#  'lebih': {'arif': 1,
#   'banyak': 1,
#   'bijak': 1,
#   'lama': 1,
#   'tabah': 1,
#   'tidak': 1},
#  'lepaskan': {'kisah': 1},
#  'letih': {'letihnya': 1},
#  'letihnya': {'kucari': 1},
#  'liar': {'pacu': 1},
#  'lilin': {'di': 1},
#  'lima': {'anak': 1},
#  'luar': {'hitungan': 1, 'segala': 1, 'sepi': 1},
#  'luka': {'antara': 1, 'dan': 1, 'siapa': 1},
#  'lupa': {'tiba': 1, 'untuk': 1},
#  'luput': {'sesaat': 1},
#  'lurus': {'kaku': 1},
#  'madu': {'cerita': 1, 'jika': 1},
#  'maju': {'bagimu': 1, 'dan': 1, 'serbu': 1},
#  'makna': {'bagiku': 1},
#  'malam': {'ada': 1,
#   'buta': 1,
#   'dalam': 1,
#   'dan': 1,
#   'ganggang': 1,
#   'membenam': 1,
#   'sepi': 2,
#   'tambah': 1},
#  'mana': {'dia': 1, 'rumah': 1},
#  'manis': {'madu': 1},
#  'marah': {'beta': 1},
#  'mari': {'beria': 1, 'berlupa': 1, 'kita': 3, 'menari': 1},
#  'masa': {'pembangunan': 1},
#  'masih': {'ingin': 1, 'menggelombang': 1, 'menyebut': 1, 'pengap': 1},
#  'matahari': {'memaksaku': 1, 'merindukanku': 1, 'tak': 1},
#  'matamu': {'bagiku': 1, 'kembang': 1},
#  'matanya': {'menatap': 1},
#  'mati': {'datang': 1, 'doa': 1, 'gadis': 1, 'muda': 1},
#  'mau': {'berpaut': 1, 'hidup': 1, 'lebih': 1, 'tak': 1},
#  'mawar': {'dan': 1},
#  'mayat': {'berikan': 1},
#  'melangkah': {'ke': 1},
#  'melati': {'harum': 1},
#  'melayang': {'jatuh': 1, 'untuk': 1},
#  'melepas': {'renggut': 1},
#  'melihat': {'selama': 1},
#  'memagut': {'tak': 1},
#  'memaksaku': {'menciptakan': 1},
#  'membakar': {'pulau': 1},
#  'membayangkan': {'keindahan': 1},
#  'membelah': {'aku': 1},
#  'membenam': {'layar': 1},
#  'membenci': {'angin': 1},
#  'memberat': {'mencekung': 1},
#  'memberi': {'pamit': 1},
#  'memerdu': {'jiwa': 1, 'lagu': 1},
#  'memimpikan': {'tanah': 1},
#  'mempercaya': {'mau': 1},
#  'mempercayai': {'janji': 1},
#  'mempercepat': {'kelam': 1},
#  'memperhitungkan': {'ati': 1},
#  'mempesiang': {'diriku': 1},
#  'memungut': {'detik': 1},
#  'menagih': {'yang': 1},
#  'menanti': {'jadi': 1, 'menanti': 2, 'senja': 1, 'sepi': 1, 'tak': 1},
#  'menari': {'mari': 1, 'menurut': 1, 'seluruh': 1},
#  'menarik': {'kita': 2, 'menari': 1},
#  'menatap': {'orang': 1},
#  'mencari': {'cinta': 1},
#  'mencekik': {'diri': 1, 'memberat': 1},
#  'mencekung': {'punda': 1},
#  'mencengkam': {'dari': 1},
#  'mencintai': {'air': 1,
#   'angin': 1,
#   'api': 1,
#   'cakrawala': 1,
#   'gunung': 1,
#   'mu': 1},
#  'mencintaimu': {'dengan': 2},
#  'mencintamu': {'dengan': 1},
#  'menciptakan': {'bunga': 1},
#  'mencoba': {'bertahan': 1},
#  'mendegap': {'hati': 1},
#  'mendekat': {'dan': 1, 'tiga': 1},
#  'mendengar': {'deru': 1},
#  'menderu': {'dalam': 1},
#  'mendesak': {'lurus': 1},
#  'mendoa': {'tiba': 1},
#  'menebal': {'segala': 1},
#  'menebas': {'jarak': 1},
#  'menekan': {'mendesak': 1},
#  'menembus': {'kulitku': 1, 'tanah': 1},
#  'menemu': {'bujuk': 1},
#  'menengadah': {'selama': 1},
#  'menerjang': {'luka': 1},
#  'menerjemahkanku': {'ke': 1},
#  'mengairi': {'kemurnian': 1},
#  'mengalir': {'dari': 1},
#  'mengalun': {'bergelut': 1},
#  'mengangkat': {'kabut': 1},
#  'mengembara': {'di': 1},
#  'mengental': {'segala': 1},
#  'mengetuk': {'aku': 1},
#  'menggelepar': {'tengah': 1},
#  'menggelombang': {'dalam': 1},
#  'menggigir': {'juga': 1},
#  'menghamba': {'binasa': 1},
#  'menghembus': {'diri': 1},
#  'menghianat': {'mencengkam': 1},
#  'mengingat': {'kau': 1},
#  'meninabobokan': {'ranting': 1},
#  'meniup': {'nyawa': 1},
#  'menjadi': {'aku': 1,
#   'api': 1,
#   'jilat': 1,
#   'ricik': 1,
#   'siut': 1,
#   'terjal': 1},
#  'menjadikannya': {'abu': 1, 'tiada': 1},
#  'menjaga': {'bung': 3, 'hutan': 1},
#  'menurut': {'beta': 1},
#  'menyaksikanmu': {'bahagia': 1},
#  'menyanyi': {'malam': 1},
#  'menyebut': {'beta': 1, 'namamu': 1},
#  'menyediakan': {'api': 1},
#  'menyerahkan': {'kamar': 1},
#  'menyinar': {'ke': 1},
#  'menyinggung': {'muram': 1},
#  'menyisir': {'semenanjung': 1},
#  'meradang': {'menerjang': 1},
#  'merah': {'berkibar': 1},
#  'meraih': {'petang': 1},
#  'merangkainya': {'seperti': 1},
#  'merasa': {'angkasa': 1},
#  'merasai': {'maju': 1},
#  'merasuk': {'rimba': 1},
#  'merayu': {'pilih': 1, 'tidak': 1},
#  'merdeka': {'dan': 1},
#  'mereka': {'berada': 1},
#  'meriak': {'muka': 1},
#  'merindukanku': {'mengangkat': 1},
#  'minta': {'adik': 1, 'ampun': 1},
#  'mu': {'aku': 1,
#   'di': 2,
#   'digarami': 1,
#   'dipanggang': 1,
#   'harus': 1,
#   'panas': 1},
#  'muda': {'yang': 1},
#  'muka': {'air': 1, 'penuh': 1},
#  'mulai': {'tanggal': 1},
#  'muram': {'desir': 1},
#  'nama': {'dalam': 1},
#  'namamu': {'biar': 1},
#  'nampak': {'ku': 1},
#  'namun': {'di': 1},
#  'nanti': {'dulu': 1, 'impianku': 1, 'jasadku': 1, 'pada': 1, 'suaraku': 1},
#  'negeri': {'asing': 1, 'menyediakan': 1},
#  'nilai': {'tulang': 1},
#  'nyawa': {'kami': 1, 'rumahku': 1},
#  'ombak': {'tiada': 1},
#  'orang': {'tersalib': 1},
#  'pacu': {'laju': 1},
#  'pada': {'cerita': 1,
#   'dunia': 1,
#   'ibu': 1,
#   'siang': 1,
#   'siapa': 1,
#   'suatu': 5,
#   'tari': 1},
#  'padam': {'tolong': 1},
#  'padamu': {'dalam': 2, 'tapi': 1},
#  'pagi': {'kuhentikan': 1, 'perlahan': 1, 'terbang': 1, 'tiba': 1},
#  'pala': {'badan': 1, 'beta': 1, 'mati': 1},
#  'paling': {'liar': 1},
#  'pamit': {'siapa': 1},
#  'panas': {'suci': 1},
#  'pandang': {'yang': 1},
#  'pangkal': {'akanan': 1},
#  'pantai': {'keempat': 1, 'siapa': 1},
#  'pattirajawane': {'ketika': 1, 'kikisan': 1, 'menjaga': 1, 'yang': 2},
#  'pedang': {'di': 1},
#  'pedangmu': {'hingga': 1},
#  'pedih': {'peri': 1},
#  'peduli': {'aku': 1},
#  'pelabuhan': {'kecil': 1},
#  'pelangi': {'kau': 1},
#  'peluk': {'kucup': 1},
#  'peluru': {'menembus': 1},
#  'pembangunan': {'ini': 1},
#  'pemeluk': {'teguh': 1},
#  'pengap': {'harap': 1},
#  'penghabisan': {'bisa': 1},
#  'penjara': {'sepi': 1},
#  'penuh': {'luka': 1, 'seluruh': 1},
#  'perahu': {'tiada': 1},
#  'perawan': {'jadi': 1},
#  'perbuat': {'hilang': 1},
#  'perempuan': {'tinggalkan': 1},
#  'peri': {'dan': 1},
#  'peristiwa': {'berlaku': 1},
#  'perlahan': {'ada': 1},
#  'perlu': {'sedan': 1},
#  'pernyataan': {'dan': 1},
#  'persetujuan': {'dengan': 1},
#  'petang': {'biar': 1},
#  'pilih': {'kuda': 1},
#  'pintu': {'mu': 1, 'terbuka': 1},
#  'pohon': {'berbunga': 1, 'bunga': 1, 'pala': 1},
#  'pohonan': {'tak': 1},
#  'pula': {'menggelepar': 1},
#  'pulau': {'beta': 1},
#  'pun': {'tak': 1},
#  'punah': {'di': 1},
#  'puncak': {'sepi': 1},
#  'punda': {'sampai': 1},
#  'punya': {'ku': 1, 'nama': 1, 'tifa': 1},
#  'pusaka': {'sonder': 1},
#  'putih': {'bersandar': 1},
#  'putus': {'kelam': 1},
#  'putuskan': {'kini': 1, 'sekali': 1},
#  'ragu': {'di': 1, 'ragu': 1},
#  'rambutmu': {'mengalun': 1},
#  'ranting': {'itu': 1, 'yang': 1},
#  'rapat': {'di': 1},
#  'rasa': {'belum': 1, 'hampa': 2},
#  'rasanya': {'lama': 1},
#  'remuk': {'tuhanku': 1},
#  'renggut': {'segala': 1},
#  'ribu': {'nyawa': 1},
#  'ricik': {'mencintai': 1},
#  'rimba': {'jadi': 1},
#  'rindunya': {'kepada': 1},
#  'rintik': {'rindunya': 1},
#  'ruang': {'di': 1},
#  'rumah': {'ku': 2, 'tua': 1},
#  'rumahku': {'rumah': 1},
#  'rumput': {'nanti': 1},
#  'saja': {'aku': 1, 'jadi': 1},
#  'sajak': {'di': 1, 'ini': 3, 'kaca': 1, 'kecil': 1, 'putih': 1, 'tafsir': 1},
#  'salah': {'satu': 1},
#  'sampai': {'binasa': 1,
#   'juga': 1,
#   'ke': 1,
#   'pada': 1,
#   'pagi': 1,
#   'waktuku': 1},
#  'sampan': {'beta': 1},
#  'sapu': {'taman': 1},
#  'satu': {'beta': 1,
#   'ibuku': 1,
#   'kuasa': 1,
#   'persetujuan': 1,
#   'sajak': 1,
#   'urat': 1,
#   'zat': 1},
#  'sebagai': {'daun': 1, 'hasrat': 1},
#  'sebaris': {'lagi': 1},
#  'sebelum': {'ajal': 1, 'kau': 1},
#  'sebuah': {'jendela': 1, 'kamar': 1},
#  'sedan': {'itu': 1},
#  'sederhana': {'aku': 1, 'dengan': 2},
#  'sedu': {'penghabisan': 1},
#  'segala': {'belum': 1,
#   'dosa': 1,
#   'menanti': 1,
#   'menebal': 1,
#   'mengental': 1,
#   'nampak': 1,
#   'tak': 1},
#  'sejenak': {'berbaring': 1},
#  'sekali': {'kali': 1, 'lagi': 2, 'tiba': 1, 'tuan': 1},
#  'sekalian': {'selamat': 1},
#  'sekarang': {'api': 1, 'laut': 1, 'mayat': 1, 'yang': 1},
#  'sekeliling': {'dunia': 1},
#  'sela': {'huruf': 1, 'sela': 1},
#  'selalu': {'bapak': 1},
#  'selama': {'ini': 1, 'kau': 1, 'masih': 1, 'matamu': 1},
#  'selamat': {'jalan': 1, 'tinggal': 1},
#  'selembar': {'daun': 4},
#  'selesai': {'belum': 1},
#  'seluruh': {'aku': 1, 'cahaya': 1},
#  'semangat': {'yang': 1},
#  'semati': {'tugu': 1},
#  'semenanjung': {'masih': 1},
#  'sempat': {'disampaikan': 1, 'diucapkan': 1},
#  'sempit': {'buat': 1},
#  'senantiasa': {'luput': 1},
#  'senda': {'sepi': 1},
#  'sendiri': {'cerita': 1, 'jadi': 1, 'pada': 1, 'terbaring': 1},
#  'sendirian': {'berjalan': 1},
#  'senja': {'di': 2, 'kala': 1},
#  'senjata': {'lagi': 1},
#  'seorang': {'kan': 1},
#  'sepenuhnya': {'lantas': 1},
#  'seperti': {'bunga': 1},
#  'sepi': {'di': 1,
#   'jika': 2,
#   'memagut': 1,
#   'menekan': 1,
#   'menyanyi': 1,
#   'sekali': 1,
#   'selalu': 1,
#   'tambah': 1,
#   'terus': 1},
#  'serang': {'terjang': 1},
#  'seratus': {'kali': 1},
#  'serbu': {'serang': 1},
#  'seribu': {'tahun': 1},
#  'serta': {'rasa': 1, 'temali': 1},
#  'seru': {'menderu': 1},
#  'sesaat': {'adalah': 1},
#  'sesungguhnya': {'jalan': 1},
#  'setan': {'bertampik': 1},
#  'setiap': {'pagi': 1},
#  'siang': {'dan': 1, 'irama': 1},
#  'siapa': {'mendekat': 1, 'punya': 1, 'saja': 1, 'yang': 1},
#  'siapakah': {'yang': 1},
#  'sini': {'ada': 1, 'ajal': 1, 'aku': 2},
#  'sisimu': {'aku': 1},
#  'siut': {'mencintai': 1},
#  'sjahrir': {'kami': 1},
#  'sonder': {'kerabat': 1, 'pusaka': 1},
#  'sore': {'tiba': 1},
#  'suara': {'angin': 1},
#  'suaraku': {'tak': 1},
#  'suatu': {'hari': 5},
#  'suci': {'tinggal': 1},
#  'sudah': {'coba': 1, 'cukup': 1, 'lima': 1},
#  'suka': {'membayangkan': 1},
#  'sungai': {'ladang': 1},
#  'sungguh': {'mengingat': 1},
#  'sunyi': {'malam': 1, 'tuhanku': 1},
#  'susah': {'sungguh': 1},
#  'sutra': {'senja': 1},
#  'tabah': {'dari': 1},
#  'tafsir': {'kau': 1},
#  'tafsirkan': {'aku': 1},
#  'tafsirkanaku': {'sebagai': 1},
#  'tahu': {'kami': 1, 'sudah': 1},
#  'tahun': {'lagi': 1},
#  'tak': {'ada': 3,
#   'akan': 3,
#   'bergerak': 1,
#   'bisa': 2,
#   'dapat': 1,
#   'dikenal': 1,
#   'gentar': 1,
#   'ku': 1,
#   'perlu': 1,
#   'satu': 1,
#   'sempat': 2,
#   'seorang': 1,
#   'terdengar': 1,
#   'terucapkan': 1},
#  'tamaela': {'beta': 1},
#  'taman': {'setiap': 1},
#  'tambah': {'ini': 1, 'merasuk': 1},
#  'tanah': {'air': 1, 'basah': 1, 'tidak': 1},
#  'tangan': {'mari': 1, 'yang': 1},
#  'tanggal': {'17': 1},
#  'tanyamu': {'kita': 1},
#  'tapi': {'adalah': 1,
#   'dalam': 1,
#   'datangnya': 1,
#   'di': 1,
#   'kerja': 1,
#   'kini': 1,
#   'siapakah': 1,
#   'yang': 1},
#  'tari': {'warna': 1},
#  'teguh': {'tuhanku': 1},
#  'temali': {'kapal': 1},
#  'tembatkan': {'pada': 1},
#  'tembus': {'jelajah': 1},
#  'tengah': {'malam': 1},
#  'tentang': {'cinta': 1},
#  'tentukan': {'nilai': 1},
#  'terakhir': {'agar': 1, 'yang': 2},
#  'terampas': {'dan': 1},
#  'terbang': {'entah': 1},
#  'terbaring': {'antara': 2, 'jemu': 1},
#  'terbayang': {'kami': 1},
#  'terbuang': {'biar': 1},
#  'terbuka': {'selama': 1},
#  'tercapai': {'jika': 1},
#  'terdekap': {'kepada': 1},
#  'terdengar': {'lagi': 1},
#  'teriak': {'merdeka': 1},
#  'terjal': {'mencintai': 1},
#  'terjang': {'yang': 1},
#  'terlalu': {'sempit': 1},
#  'termangu': {'aku': 1},
#  'tersalib': {'di': 1},
#  'tersedu': {'keramaian': 1},
#  'tersesat': {'tak': 1},
#  'tertidur': {'dalam': 1},
#  'terucapkan': {'diserap': 1},
#  'terus': {'ada': 1, 'di': 1},
#  'teruskan': {'jiwa': 1, 'teruskan': 1},
#  'tetap': {'kusiasati': 1, 'meradang': 1},
#  'tiada': {'berlaut': 1, 'hatiku': 1, 'lagi': 1},
#  'tiang': {'serta': 1},
#  'tiba': {'bisa': 1, 'di': 1, 'mari': 1, 'meriak': 1, 'sajak': 1, 'tiba': 1},
#  'tidak': {'ada': 1,
#   'bergerak': 1,
#   'bisa': 2,
#   'juga': 1,
#   'lagi': 3,
#   'lupa': 1,
#   'melihat': 1,
#   'membelah': 1,
#   'memberi': 1,
#   'mempercayai': 1,
#   'minta': 1,
#   'peduli': 1,
#   'suka': 1,
#   'tahu': 1,
#   'untuk': 1},
#  'tidur': {'hilang': 1},
#  'tifa': {'pohon': 1},
#  'tiga': {'kali': 1},
#  'tikamkan': {'pedangmu': 1},
#  'timbun': {'sajak': 2},
#  'tinggal': {'diponegoro': 1, 'kerdip': 1, 'tulang': 2},
#  'tinggalkan': {'kalau': 1},
#  'tolong': {'ciptakan': 1, 'tafsirkan': 1, 'tafsirkanaku': 1},
#  'tua': {'pada': 1},
#  'tuan': {'hidup': 1, 'menanti': 1},
#  'tubuhku': {'diam': 1},
#  'tugu': {'di': 1},
#  'tuhanku': {'aku': 2, 'dalam': 1, 'di': 1},
#  'tulang': {'berserakan': 2, 'diliputi': 2, 'tulang': 3},
#  'udara': {'bertuba': 1},
#  'ujung': {'dan': 1},
#  'unggun': {'timbun': 2},
#  'untuk': {'apa': 2, 'bisa': 1, 'kemerdekaan': 1},
#  'urat': {'di': 1, 'ku': 1, 'mu': 1},
#  'waktu': {'bukan': 1, 'kita': 1, 'yang': 1},
#  'waktuku': {'aku': 1},
#  'warna': {'pelangi': 1},
#  'x': {'4': 1},
#  'y': {'a': 1},
#  'yang': {'akan': 1,
#   'berdenyut': 1,
#   'berdetak': 2,
#   'bergerak': 1,
#   'berkata': 1,
#   'dihamilkan': 1,
#   'dijaga': 2,
#   'fana': 3,
#   'ingin': 1,
#   'kami': 1,
#   'kau': 1,
#   'kini': 1,
#   'ku': 1,
#   'lebih': 3,
#   'masih': 1,
#   'membenci': 1,
#   'memimpikan': 1,
#   'menarik': 2,
#   'mencari': 1,
#   'mencoba': 1,
#   'mengairi': 1,
#   'meninabobokan': 1,
#   'menjadikannya': 2,
#   'menyinar': 1,
#   'paling': 1,
#   'putus': 1,
#   'ragu': 1,
#   'satu': 1,
#   'selama': 1,
#   'tak': 4,
#   'tentukan': 1,
#   'terampas': 1,
#   'tidak': 1,
#   'tinggal': 2},
#  'zat': {'ku': 1, 'mu': 1, 'satu': 1}}

# %%
bcount
# Out:
# 1341

# %%
#Handle unseen word
def getGT(tokens, unigram_count):
    bigram_max = unigram_count * unigram_count
    bigram, bigram_count = getBigram(tokens)
    bigram_unseen = bigram_max - bigram_count
    
    num_of_gram_of_counts = [bigram_unseen, 0, 0, 0, 0, 0]
    for first in bigram:
        for second in bigram[first]:
            counter = bigram[first][second]
            if counter < 6:
                num_of_gram_of_counts[counter] += 1

    GT_counts = [0, 0, 0, 0, 0]
    for x in range(0, 5):
        GT_counts[x] = (x + 1) * (num_of_gram_of_counts[x + 1] * 1.0000) / (num_of_gram_of_counts[x] * 1.0000)
    return GT_counts

# %%
gt_count = getGT(tokens,ucount)
gt_count
# Out:
# [0.0026194227409622414,
#  0.13584288052373159,
#  0.8674698795180723,
#  1.1666666666666667,
#  2.857142857142857]

# %%
#Calculate Probability
def probability(first, second, unigram, bigram, gt_counts):
    counter = 0
    if second.lower() in bigram[first.lower()]:
        counter = bigram[first.lower()][second.lower()]
    if counter < 5:
        counter = gt_counts[counter]
    return counter / (unigram[first.lower()] * 1.0)

# %%
p= probability('Matahari', 'bangkit', unigram, bigram,gt_count)
p
# Out:
# 0.0008731409136540805

# %%
#Calculate perplexity
def compute_perplexity(tester, trainer1, trainer2):
    tokens_tester = startToken(tester)
    tokens_trainer = startToken(trainer1)
    getToken(tokens_trainer, trainer2)

    unigram, ucount = getUnigram(tokens_trainer)
    bigram, bcount = getBigram(tokens_trainer)
    gt_count = getGT(tokens_trainer, ucount)

    tokens_tester_count = len(tokens_tester)

    unk = 'unknown'
    length = len(tokens_tester)
    for i in range(0, length, 1):
        if tokens_tester[i] not in unigram:
            tokens_tester[i] = unk
            if unk not in unigram:
                unigram[unk] = 1
            else:
                unigram[unk] += 1
            if 'unknown' not in bigram:
                bigram[unk] = {}
                bigram[unk][unk] = 1
                
            else:
                bigram[unk][unk] += 1


    total = 0
    for x in range(0, length - 1):
        prob = probability(tokens_tester[x], tokens_tester[x + 1], unigram, bigram, gt_count)
        total += math.log(prob)*(-1)

    return math.exp((total / length))

# %%
perplexity = compute_perplexity('Tester.txt', 'Khairil Anwar.txt', 'Sapardi Darnomo.txt')
perplexity
# Out:
# 1149.0090464651273

# %%
#Generate Poetry
def generatePoetry(trainer1, trainer2, maxwordcount):
    token = startToken(trainer1)
    getToken(token, trainer2)

    unigram, ucount = getUnigram(tokens)
    bigram, bcount = getBigram(tokens)
    gt_count = getGT(tokens, ucount)
    
    sentences = ''
    wordcount = 0
    lastWord = ''
    lastProb = 0
    currentProb = 0
    maxProb = 0
    
    while (wordcount < maxwordcount):
        if (wordcount == 0):
            for word,count in unigram.items():
                currentProb = count / len(token)
                if maxProb < currentProb:
                    maxProb = currentProb
                    lastWord = word
                    
            sentences += lastWord
            lastProb = maxProb
            wordcount += 1
            
        else:
            if lastWord not in bigram:
                maxProb = 0
                for word,count in unigram.items():
                    currentProb = count / len(token)
                    if  maxProb < currentProb:
                        maxProb = currentProb 
                        lastWord = word
                        
            else:
                maxProb = 0
                for word in bigram[lastWord]:
                    currentProb = lastProb * probability( lastWord, word, unigram, bigram,gt_count)
                    if  maxProb < currentProb:
                        maxProb = currentProb 
                        lastWord = word
                        
            sentences += ' '
            sentences += lastWord
            lastProb = maxProb
            wordcount += 1
    print(lastProb)        
    return sentences

# %%
generatePoetry('Khairil Anwar.txt', 'Sapardi Darnomo.txt', 100)
# Out:
# 1.8909501595948623e-144
# 'yang tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak seorang kan merayu tidak juga kau tak'

# %%
#unigrams Best 5
maxUni = dict(sorted(unigram.items(), key=operator.itemgetter(1), reverse=True)[:10])
maxUni
# Out:
# {'aku': 36,
#  'dalam': 18,
#  'dan': 32,
#  'dari': 13,
#  'di': 42,
#  'kami': 19,
#  'lagi': 18,
#  'tak': 20,
#  'tidak': 18,
#  'yang': 46}

# %%
#Calculate perplexity (unigram)
def compute_perplexity(tester, trainer1, trainer2):
    tokens_tester = startToken(tester)
    tokens_trainer = startToken(trainer1)
    getToken(tokens_trainer, trainer2)

    unigram, ucount = getUnigram(tokens_trainer)
    bigram, bcount = getBigram(tokens_trainer)
    gt_count = getGT(tokens_trainer, ucount)

    tokens_tester_count = len(tokens_tester)

    unk = 'unknown'
    length = len(tokens_tester)
    for i in range(0, length, 1):
        if tokens_tester[i] not in unigram:
            tokens_tester[i] = unk
            if unk not in unigram:
                unigram[unk] = 1
            else:
                unigram[unk] += 1
            if 'unknown' not in bigram:
                bigram[unk] = {}
                bigram[unk][unk] = 1
                
            else:
                bigram[unk][unk] += 1


    total = 0
    for x in range(0, length - 1):
        prob = unigram[tokens_tester[x]] / len(tokens_trainer)
        total += math.log(prob)*(-1)

    return math.exp((total / length))

# %%
perplexity = compute_perplexity('Tester.txt', 'Khairil Anwar.txt', 'Sapardi Darnomo.txt')
perplexity
